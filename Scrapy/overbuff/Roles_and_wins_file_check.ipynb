# %%
import pandas as pd

# %%
data = pd.read_csv('roles_and_wins.csv')
data
# Out:
#             Battle_Tag Total_Wins Top_role_0  role_wins_0 Top_role_1  \
# 0        Morellio-1416        934    Support        424.0       Tank
# 1           Zinux-1251         85       Tank         12.0    Defense
# 2     BluePillow-21338        542    Defense        283.0    Offense
# 3         Miyuna-21516         62    Offense         15.0    Defense
# 4           Mood-21538        190    Defense         84.0    Offense
# ...                ...        ...        ...          ...        ...
# 1609      LOBBER-11224        241       Tank         56.0    Offense
# 1610       Frisk-31639          0        NaN          NaN        NaN
# 1611       Maple-21960        285       Tank         98.0    Offense
# 1612  PKBlizzard-21364        109    Defense         10.0    Support
# 1613       Daaxyy-1605        434       Tank          8.0    Support
#
#       role_wins_1 Top_role_2  role_wins_2 Top_role_3  role_wins_3
# 0           435.0    Offense         41.0    Defense         34.0
# ...
