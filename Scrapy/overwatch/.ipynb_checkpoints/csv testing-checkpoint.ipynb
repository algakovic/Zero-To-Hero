# %%
import pandas as pd

# %%
ls
# Out:
# Testing Ground.ipynb       overwatch/
# Untitled.ipynb             scrapy.cfg
# df_comp_elim_permin.csv    tagnames.csv
# heros_for_playerstop5.csv

# %%
df1 = pd.read_csv('heros_for_playerstop5.csv')
df2 = pd.read_csv('df_comp_elim_permin.csv').replace('#', '-')
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,2,5,8,9,12,13,14,15,16,17,20,24,25,26,27,28,29,30,33,34,38,40,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2.Battle_Tag = df2.Battle_Tag.apply(lambda x: x.replace('#','-'))
# Out:
#                Battle_Tag  Level   Skill Rating  K/d Ratio  Ka/d Ratio  Win %  \
# 0           Morellio#1416  2,999  1,297,591,865       1.48        2.26  50.7%
# 1              Zinux#1251    422     29,053,161       4.68        5.32  76.7%
# 2        BluePillow#21338    625     28,042,860       2.33        2.72  80.0%
# 3            Miyuna#21516     57     25,273,056       2.71        2.96  70.0%
# 4              Mood#21538    459     25,382,447       2.01        2.84  34.2%
# ...                   ...    ...            ...        ...         ...    ...
# 190529         Boda#21886    NaN            NaN        NaN         NaN    NaN
# 190530         mikel#2810    NaN            NaN        NaN         NaN    NaN
# 190531         mhjcg#1166    NaN            NaN        NaN         NaN    NaN
# 190532  worldstar420#1847    NaN            NaN        NaN         NaN    NaN
# 190533        MrYan#21963    NaN            NaN        NaN         NaN    NaN
#
#         Kills per Game  Eliminations per Game Damage per Game  \
# 0                14.21                  14.21        5,237.64
# 1                33.84                  33.84       15,140.02
# 2                25.33                  25.33        9,547.33
# 3                22.80                  22.80        7,987.43
# 4                18.66                  18.66        7,424.13
# ...                ...                    ...             ...
# 190529             NaN                    NaN             NaN
# 190530             NaN                    NaN             NaN
# 190531             NaN                    NaN             NaN
# 190532             NaN                    NaN             NaN
# 190533             NaN                    NaN             NaN
#
#        Healing per Game  ...  Most Offensive Assists  Most Objective Kills  \
# 0              2,307.95  ...                     0.0                  29.0
# 1              1,262.35  ...                     0.0                  25.0
# 2                886.13  ...                     0.0                  16.0
# 3                578.83  ...                     0.0                  19.0
# 4              1,861.95  ...                     0.0                  17.0
# ...                 ...  ...                     ...                   ...
# 190529              NaN  ...                     NaN                   NaN
# 190530              NaN  ...                     NaN                   NaN
# 190531              NaN  ...                     NaN                   NaN
# 190532              NaN  ...                     NaN                   NaN
# 190533              NaN  ...                     NaN                   NaN
#
#        Most Objective Time Most Solo Kills Most Time Spent On Fire Cards  \
# 0                   7m 40s            22.0                  5m 32s  43.0
# 1                   6m 20s            36.0                  9m 10s  31.0
# 2                    5m 6s            25.0                  4m 39s   5.0
# 3                   4m 21s            24.0                  4m 51s   0.0
# 4                   2m 33s            28.0                  5m 23s   7.0
# ...                    ...             ...                     ...   ...
# 190529                 NaN             NaN                     NaN   NaN
# 190530                 NaN             NaN                     NaN   NaN
# 190531                 NaN             NaN                     NaN   NaN
# 190532                 NaN             NaN                     NaN   NaN
# 190533                 NaN             NaN                     NaN   NaN
#
#        Medals Gold Medals  Silver Medals  Bronze Medals
# 0         276          72          100.0          104.0
# 1         137          80           34.0           23.0
# 2          31          12           12.0            7.0
# 3          67          12           21.0           34.0
# 4          72          20           30.0           22.0
# ...       ...         ...            ...            ...
# 190529    NaN         NaN            NaN            NaN
# 190530    NaN         NaN            NaN            NaN
# 190531    NaN         NaN            NaN            NaN
# 190532    NaN         NaN            NaN            NaN
# 190533    NaN         NaN            NaN            NaN
#
# [190534 rows x 46 columns]
